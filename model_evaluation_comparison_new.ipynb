# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc

# %%
models = ["Bert",
    "RoBERTa (default)", "RoBERTa (3-fold + fine-tuning)", "RoBERTa + Extra Features",
    "SVM (Linear Kernel)", "SVM (RBF Kernel)", "XLNet"
]

# %%
accuracy = [60.9,52.6, 65.2, 62.3, 63.0, 61.6, 60.9]
precision = [67.12,66.15, 72.8, 67.4, 80, 86, 61.19]
recall = [62.03,50.59, 69.4, 75.3, 53, 45, 59.42]
f1_scores = [64.47,57.33, 71.1, 71.1, 64.47, 59.0, 60.29]
print(len(accuracy))
print(len(precision))
print(len(recall))
print(len(f1_scores))
# Out:
# 7
# 7
# 7
# 7

# %%
df = pd.DataFrame({
    "Model": models,
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1_scores
})

# %%
df.set_index("Model").plot(kind='bar', figsize=(12, 6), colormap='viridis', edgecolor='black')
plt.title("Performance Comparison of Sarcasm Detection Models")
plt.ylabel("Score")
plt.xticks(rotation=30, ha='right')
plt.legend(loc='lower right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from math import pi

# Normalize values for better visualization
normalized_metrics = df.set_index("Model") / df.set_index("Model").max()

# Define categories
categories = list(df.columns[1:])
num_vars = len(categories)

# Create a radar chart for each model
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Close the circular plot

plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

for i, model in enumerate(models):
    values = normalized_metrics.iloc[i].tolist()
    values += values[:1]  # Close the shape
    ax.plot(angles, values, label=model, linewidth=2, linestyle='solid')
    ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)
plt.title("Radar Chart - Model Comparison")
plt.legend(loc="upper right", bbox_to_anchor=(1.2, 1))
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.set_index("Model").corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Performance Metrics")
plt.show()

# %%
import plotly.express as px

fig = px.line_polar(df.melt(id_vars=["Model"], var_name="Metric", value_name="Score"),
                    r="Score", theta="Metric", color="Model", line_close=True)
fig.update_layout(title="Radar Chart - Model Performance", template="plotly_dark")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7fc04a14-e6f3-4ab9-b5f8-5d36b1fa9ac9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fc04a14-e6f3-4ab9-b5f8-5d36b1fa9ac9")) {                    Plotly.newPlot(                        "7fc04a14-e6f3-4ab9-b5f8-5d36b1fa9ac9",                        [{"hovertemplate":"Model=Bert\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bert","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bert","r":[60.9,67.12,62.03,64.47,60.9],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"},{"hovertemplate":"Model=RoBERTa (default)\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RoBERTa (default)","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RoBERTa (default)","r":[52.6,66.15,50.59,57.33,52.6],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"},{"hovertemplate":"Model=RoBERTa (3-fold + fine-tuning)\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RoBERTa (3-fold + fine-tuning)","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RoBERTa (3-fold + fine-tuning)","r":[65.2,72.8,69.4,71.1,65.2],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"},{"hovertemplate":"Model=RoBERTa + Extra Features\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RoBERTa + Extra Features","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RoBERTa + Extra Features","r":[62.3,67.4,75.3,71.1,62.3],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"},{"hovertemplate":"Model=SVM (Linear Kernel)\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SVM (Linear Kernel)","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SVM (Linear Kernel)","r":[63.0,80.0,53.0,64.47,63.0],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"},{"hovertemplate":"Model=SVM (RBF Kernel)\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SVM (RBF Kernel)","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SVM (RBF Kernel)","r":[61.6,86.0,45.0,59.0,61.6],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"},{"hovertemplate":"Model=XLNet\u003cbr\u003eScore=%{r}\u003cbr\u003eMetric=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"XLNet","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"XLNet","r":[60.9,61.19,59.42,60.29,60.9],"showlegend":true,"subplot":"polar","theta":["Accuracy","Precision","Recall","F1 Score","Accuracy"],"type":"scatterpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"typ ...
